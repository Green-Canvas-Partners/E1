# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np

import sys
import os
# Current working directory in Jupyter Notebook
project_root = os.getcwd()  # Current working directory
project_root = os.path.join(project_root, '..')  # Move one level up to the root
sys.path.append(project_root)
# from importlib import reload
# import utils.custom
# reload(utils.custom)
from utils.custom import calculate_metrics, plot_returns
from definitions.constants import LIVE_STOCK_DICT_PATH, LIVE_RETURNS_PATH

with open(LIVE_RETURNS_PATH, 'rb') as f:
    returns = pickle.load(f)

# %%
with open(LIVE_STOCK_DICT_PATH, 'rb') as f:
    dictt = pickle.load(f)

dictt
# Out:
# {'2024-01-31': array(['NVDA', 'AMD', 'TQQQ'], dtype=object),
#  '2024-02-29': array(['NVDA', 'AMD', 'TQQQ'], dtype=object),
#  '2024-03-28': array(['NVDA', 'TQQQ', 'AMD'], dtype=object),
#  '2024-04-30': array(['NVDA', 'GOOGL', 'AMZN'], dtype=object),
#  '2024-05-31': array(['NVDA', 'TQQQ', 'SLV'], dtype=object),
#  '2024-06-28': array(['NVDA', 'TQQQ', 'GOOGL'], dtype=object),
#  '2024-07-31': array(['NVDA', 'TQQQ', 'AAPL'], dtype=object),
#  '2024-08-30': array(['NVDA', 'TQQQ', 'AAPL'], dtype=object),
#  '2024-09-30': array(['NVDA', 'TQQQ', 'TSLA'], dtype=object),
#  '2024-10-31': array(['NVDA', 'TSLA', 'SLV'], dtype=object),
#  '2024-11-29': array(['TSLA', 'NVDA', 'TQQQ'], dtype=object),
#  '2024-12-26': array([], dtype=float64)}

# %%
returns.tail(30)
# Out:
# 2024-01-31    23.305173
# 2024-02-29     5.060407
# 2024-03-28   -10.350177
# 2024-04-30    20.295305
# 2024-05-31     9.064431
# 2024-06-28    -5.896364
# 2024-07-31    -1.022810
# 2024-08-30     5.027811
# 2024-09-30     4.622641
# 2024-10-31    12.075898
# 2024-11-29     0.000000
# 2024-12-26     0.000000
# dtype: float64

# %%
annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns)

# Print results
print(f"Annual Return: {annual_return * 100:.2f}%")
print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
print(f"Calmar Ratio: {calmar_ratio:.2f}")
print(f"Sortino Ratio: {sortino_ratio:.2f}")
# Out:
# Annual Return: 74.78%
# Sharpe Ratio: 1.90
# Max Drawdown: 10.35%
# Calmar Ratio: 7.22
# Sortino Ratio: 4.71

# %%
plot_returns(returns)
