# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np

import sys
import os
# Current working directory in Jupyter Notebook
project_root = os.getcwd()  # Current working directory
project_root = os.path.join(project_root, '..')  # Move one level up to the root
sys.path.append(project_root)
# from importlib import reload
# import utils.custom
# reload(utils.custom)
from utils.custom import calculate_metrics, plot_returns
from definitions.constants import *

# %%
df=pd.read_csv(GS_RES)
df
# Out:
#        qt  topnStocksByVolume  nStockspos_plus_topnStockSelect  \
# 0    0.05                  10                                2
# 1    0.05                  10                                2
# 2    0.05                  10                                2
# 3    0.05                  10                                2
# 4    0.05                  10                                4
# ..    ...                 ...                              ...
# 139  0.20                  27                                6
# 140  0.20                  27                                8
# 141  0.20                  27                                8
# 142  0.20                  27                                8
# 143  0.20                  27                                8
#
#      topnStockSelect  momentum_windows  half_lives  annual_returns  \
# 0                  1                30          30        0.427624
# 1                  1                30          63        0.241346
# 2                  1                63          30        0.657595
# 3                  1                63          63        0.669172
# 4                  3                30          30        0.396516
# ..               ...               ...         ...             ...
# 139                1                63          63        0.327984
# 140                3                30          30        0.177085
# 141                3                30          63        0.130618
# 142                3                63          30        0.263038
# 143                3                63          63        0.318410
#
#      sharpe_ratios  max_drawdown_values  calmar_ratios  sortino_ratios
# 0         1.115227             0.334282       1.279231        2.531464
# 1         0.751009             0.334282       0.721985        1.614750
# 2         1.418477             0.354155       1.856802        4.737561
# 3         1.309680             0.387097       1.728696        3.790116
# 4         1.273063             0.273759       1.448411        2.249761
# ..             ...                  ...            ...             ...
# 139       0.854925             0.307305       1.067291        1.674899
# 140       0.651602             0.454735       0.389424        1.055564
# 141       0.546589             0.439123       0.297452        0.896610
# 142       0.913377             0.346187       0.759814        2.093291
# 143       1.002513             0.334875       0.950834        2.099742
#
# [144 rows x 11 columns]

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df
# Out:
#        qt  topnStocksByVolume  nStockspos_plus_topnStockSelect  \
# 0    0.05                  10                                2
# 1    0.05                  10                                2
# 2    0.05                  10                                2
# 3    0.05                  10                                2
# 4    0.05                  10                                4
# ..    ...                 ...                              ...
# 139  0.20                  27                                6
# 140  0.20                  27                                8
# 141  0.20                  27                                8
# 142  0.20                  27                                8
# 143  0.20                  27                                8
#
#      topnStockSelect  momentum_windows  half_lives  annual_returns  \
# 0                  1                30          30        0.427624
# 1                  1                30          63        0.241346
# 2                  1                63          30        0.657595
# 3                  1                63          63        0.669172
# 4                  3                30          30        0.396516
# ..               ...               ...         ...             ...
# 139                1                63          63        0.327984
# 140                3                30          30        0.177085
# 141                3                30          63        0.130618
# 142                3                63          30        0.263038
# 143                3                63          63        0.318410
#
#      sharpe_ratios  max_drawdown_values  calmar_ratios  sortino_ratios
# 0         1.115227             0.334282       1.279231        2.531464
# 1         0.751009             0.334282       0.721985        1.614750
# 2         1.418477             0.354155       1.856802        4.737561
# 3         1.309680             0.387097       1.728696        3.790116
# 4         1.273063             0.273759       1.448411        2.249761
# ..             ...                  ...            ...             ...
# 139       0.854925             0.307305       1.067291        1.674899
# 140       0.651602             0.454735       0.389424        1.055564
# 141       0.546589             0.439123       0.297452        0.896610
# 142       0.913377             0.346187       0.759814        2.093291
# 143       1.002513             0.334875       0.950834        2.099742
#
# [144 rows x 11 columns]

# %%
single_run_config = df[
    (df['qt'] == DV_QUANTILE_THRESHOLD) &
    (df['topnStocksByVolume'] == SELECTED_TOP_VOL_STOCKS) &
    (df['nStockspos_plus_topnStockSelect'] == SELECTED_N_STOCK_POSITIVE) &
    (df['topnStockSelect'] == SELECTED_N_STOCK_CHOSE) &
    (df['momentum_windows'] == SELECTED_MOM_WINDOW) &
    (df['half_lives'] == SELECTED_HALF_LIFE_WINDOW)
]

print(single_run_config)
# Out:
#      qt  topnStocksByVolume  nStockspos_plus_topnStockSelect  topnStockSelect  \
# 0  0.05                  10                                2                1
#
#    momentum_windows  half_lives  annual_returns  sharpe_ratios  \
# 0                30          30        0.427624       1.115227
#
#    max_drawdown_values  calmar_ratios  sortino_ratios
# 0             0.334282       1.279231        2.531464

# %%
df.sort_values('sharpe_ratios', ascending=False)[:2500]
# Out:
#           qt  topnStocksByVolume  nStockspos_plus_topnStockSelect  \
# 188320  0.50                 150                              107
# 225222  0.66                  75                               55
# 223038  0.66                  75                               55
# 225390  0.66                  75                               55
# 188319  0.50                 150                              107
# ...      ...                 ...                              ...
# 162279  0.50                  27                               22
# 128792  0.33                 125                               55
# 126048  0.33                 125                               53
# 126608  0.33                 125                               55
# 35102   0.05                 200                               85
#
#         topnStockSelect  momentum_windows  half_lives  annual_returns  \
# 188320                7               252         250        0.243899
# 225222               30               252         150        0.271946
# 223038               50               252         150        0.271946
# 225390                5               252         150        0.278051
# 188319                7               252         200        0.223661
# ...                 ...               ...         ...             ...
# 162279                7               252         200        0.170681
# 128792               30               252         250        0.208669
# 126048               50               252         250        0.208669
# 126608               50               252         250        0.208669
# 35102                10               252         150        0.195188
#
#         sharpe_ratios  max_drawdown_values  calmar_ratios  sortino_ratios
# 188320       1.337891             0.162907       1.497166        2.302068
# 225222       1.310599             0.218466       1.244798        2.333906
# 223038       1.310599             0.218466       1.244798        2.333906
# 225390       1.308778             0.223407       1.244597        2.351043
# 188319       1.261901             0.133981       1.669357        2.198993
# ...               ...                  ...            ...             ...
# 162279       0.913237             0.199987       0.853459        1.679600
# 128792       0.913223             0.325502       0.641068        1.374731
# 126048       0.913223             0.325502       0.641068        1.374731
# 126608       0.913223             0.325502       0.641068        1.374731
# 35102        0.913156             0.348781       0.559629        1.384050
#
# [2500 rows x 11 columns]

# %%
df[
    (df['qt'] == 0.2) &
    (df['topnStocksByVolume'] == 150) &
    (df['nStockspos_plus_topnStockSelect'] == 55) &
    (df['momentum_windows'] == 252) &
    (df['half_lives'] == 250)
]
# Out:
#         qt  topnStocksByVolume  nStockspos_plus_topnStockSelect  \
# 79232  0.2                 150                               55
# 81416  0.2                 150                               55
# 81640  0.2                 150                               55
#
#        topnStockSelect  momentum_windows  half_lives  annual_returns  \
# 79232               50               252         250        0.240472
# 81416               30               252         250        0.240472
# 81640                5               252         250        0.242968
#
#        sharpe_ratios  max_drawdown_values  calmar_ratios  sortino_ratios
# 79232       1.019726             0.303152       0.793237        1.621136
# 81416       1.019726             0.303152       0.793237        1.621136
# 81640       1.014276             0.306256       0.793350        1.611847

# %%
data = df.sort_values('sharpe_ratios', ascending=False)

# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'qt' in the top 50
top_50_qt_counts = data_top_50['qt'].value_counts()

# Counting total occurrences of 'qt' in the full DataFrame
total_qt_counts = data_sorted['qt'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
qt_proportions = (top_50_qt_counts / len(data_top_50)) * 100

# Displaying the result
print(qt_proportions)
# Out:
# qt
# 0.20    22.76
# 0.05    21.00
# 0.50    17.48
# 0.66    12.28
# 0.75    12.12
# 0.33     9.32
# 0.90     5.04
# Name: count, dtype: float64

# %%
data = df.sort_values('sharpe_ratios', ascending=False)

# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'topnStocksByVolume' in the top 50
top_50_topnStocksByVolume_counts = data_top_50['topnStocksByVolume'].value_counts()

# Counting total occurrences of 'topnStocksByVolume' in the full DataFrame
total_topnStocksByVolume_counts = data_sorted['topnStocksByVolume'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
topnStocksByVolume_proportions = (top_50_topnStocksByVolume_counts / len(data_top_50)) * 100

# Displaying the result
print(topnStocksByVolume_proportions)
# Out:
# topnStocksByVolume
# 150    20.92
# 200    14.28
# 100    13.92
# 75     12.20
# 125    11.92
# 20      9.40
# 35      8.40
# 27      5.04
# 50      3.36
# 10      0.56
# Name: count, dtype: float64

# %%
data = df.sort_values('sharpe_ratios', ascending=False)

# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'nStockspos_plus_topnStockSelect' in the top 50
top_50_nStockspos_plus_topnStockSelect_counts = data_top_50['nStockspos_plus_topnStockSelect'].value_counts()

# Counting total occurrences of 'nStockspos_plus_topnStockSelect' in the full DataFrame
total_nStockspos_plus_topnStockSelect_counts = data_sorted['nStockspos_plus_topnStockSelect'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
nStockspos_plus_topnStockSelect_proportions = (top_50_nStockspos_plus_topnStockSelect_counts / len(data_top_50)) * 100

# Displaying the result
print(nStockspos_plus_topnStockSelect_proportions.sort_values(ascending=False).head(30))
# Out:
# nStockspos_plus_topnStockSelect
# 55     7.52
# 53     4.56
# 75     4.32
# 80     4.20
# 51     3.92
# 100    3.84
# 18     3.80
# 57     3.76
# 26     2.72
# 105    2.72
# 22     2.56
# 16     2.40
# 17     2.32
# 96     2.32
# 71     2.24
# 21     2.00
# 91     1.84
# 110    1.76
# 85     1.72
# 12     1.68
# 61     1.68
# 66     1.68
# 82     1.60
# 28     1.52
# 50     1.48
# 107    1.48
# 65     1.44
# 60     1.44
# 76     1.40
# 36     1.36
# Name: count, dtype: float64

# %%
data = df.sort_values('sharpe_ratios', ascending=False)

# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'topnStockSelect' in the top 50
top_50_topnStockSelect_counts = data_top_50['topnStockSelect'].value_counts()

# Counting total occurrences of 'topnStockSelect' in the full DataFrame
total_topnStockSelect_counts = data_sorted['topnStockSelect'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
topnStockSelect_proportions = (top_50_topnStockSelect_counts / len(data_top_50)) * 100

# Displaying the result
print(topnStockSelect_proportions.sort_values(ascending=False))
# Out:
# topnStockSelect
# 50    17.56
# 30    10.76
# 21    10.60
# 16    10.16
# 25     9.76
# 1      9.00
# 7      8.92
# 10     8.84
# 5      7.56
# 3      6.84
# Name: count, dtype: float64

# %%
data = df.sort_values('sharpe_ratios', ascending=False)
data['momentum_windows']=data['momentum_windows'].apply(lambda x: str(x))
# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'expWeight' in the top 50
top_50_momentum_windows_counts = data_top_50['momentum_windows'].value_counts()

# Counting total occurrences of 'expWeight' in the full DataFrame
total_momentum_windows_counts = data_sorted['momentum_windows'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
momentum_windows_proportions = (top_50_momentum_windows_counts / len(data_top_50)) * 100

# Displaying the result
print(momentum_windows_proportions)
# Out:
# momentum_windows
# 252    68.68
# 200    15.28
# 504    12.72
# 126     3.28
# 150     0.04
# Name: count, dtype: float64

# %%
data = df.sort_values('sharpe_ratios', ascending=False)
data['half_lives']=data['half_lives'].apply(lambda x: str(x))
# Sorting the DataFrame based on annual returns in descending order
data_sorted = data.sort_values(by='sharpe_ratios', ascending=False)

# Selecting the top 50 rows
data_top_50 = data_sorted.head(2500)

# Counting occurrences of 'expWeight' in the top 50
top_50_half_lives_counts = data_top_50['half_lives'].value_counts()

# Counting total occurrences of 'expWeight' in the full DataFrame
total_half_lives_counts = data_sorted['half_lives'].value_counts()

# Calculating the percentage of occurrence in the top 50 relative to total occurrences
half_lives_proportions = (top_50_half_lives_counts / len(data_top_50)) * 100

# Displaying the result
print(half_lives_proportions)
# Out:
# half_lives
# 250    31.20
# 200    21.88
# 150    21.68
# 126    14.96
# 90      9.52
# 63      0.76
# Name: count, dtype: float64
