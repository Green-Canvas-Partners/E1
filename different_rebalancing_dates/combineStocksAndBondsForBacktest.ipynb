# %%
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import numpy as np

import sys
import os
# Current working directory in Jupyter Notebook
project_root = os.getcwd()  # Current working directory
project_root = os.path.join(project_root, '..')  # Move one level up to the root
sys.path.append(project_root)
# from importlib import reload
# import utils.custom
# reload(utils.custom)
from utils.custom import calculate_metrics, plot_returns
from definitions.constants import DIFF_REBALANCING_STOCK_DICT_ALL_PKL, DIFF_REBALANCING_RETURNS_ALL_PKL #DIFF_REBALANCING_COMBINED_DATA_CSV


# dfsfilename=DIFF_REBALANCING_COMBINED_DATA_ALL_CSV
# dfsfilename=dfsfilename
# picasodfs=pd.read_pickle(dfsfilename)

stock_dict_filename=DIFF_REBALANCING_STOCK_DICT_ALL_PKL
stock_dict_filename=stock_dict_filename
stks=pd.read_pickle(stock_dict_filename)

rets_filename=DIFF_REBALANCING_RETURNS_ALL_PKL
rets_filename=rets_filename
retss=pd.read_pickle(rets_filename)

# %%
# picasodfs[0]

# %%
retss[0]
# Out:
#               returns
# t
# 2023-01-31  18.586463
# 2023-02-28  -3.055138
# 2023-03-31   1.203243
# 2023-04-28  23.454158
# 2023-05-31  10.465328
# 2023-06-30  -3.699953
# 2023-07-31   7.956421
# 2023-08-31   9.266051
# 2023-09-29  -7.640637
# 2023-10-31  10.880250
# 2023-11-30  13.474362
# 2023-12-29  17.320488
# 2024-01-31  28.824477
# 2024-02-29  12.873750
# 2024-03-28  -5.783010
# 2024-04-30  -2.126374
# 2024-05-31   8.668292
# 2024-06-28  -4.810885
# 2024-07-31  -5.459177
# 2024-08-30   3.050453
# 2024-09-30  -4.045761
# 2024-10-31  36.969870
# 2024-11-29   0.000000

# %%
stks[0]
# Out:
# {'2023-01-31': array(['TSLA'], dtype=object),
#  '2023-02-28': array(['TSLA'], dtype=object),
#  '2023-03-31': array(['NVDA'], dtype=object),
#  '2023-04-28': array(['TQQQ'], dtype=object),
#  '2023-05-31': array(['NVDA'], dtype=object),
#  '2023-06-30': array(['TSLA'], dtype=object),
#  '2023-07-31': array(['UCO'], dtype=object),
#  '2023-08-31': array(['UCO'], dtype=object),
#  '2023-09-29': array(['UCO'], dtype=object),
#  '2023-10-31': array(['MSFT'], dtype=object),
#  '2023-11-30': array(['TQQQ'], dtype=object),
#  '2023-12-29': array(['AMD'], dtype=object),
#  '2024-01-31': array(['NVDA'], dtype=object),
#  '2024-02-29': array(['NVDA'], dtype=object),
#  '2024-03-28': array(['NVDA'], dtype=object),
#  '2024-04-30': array(['TSLA'], dtype=object),
#  '2024-05-31': array(['NVDA'], dtype=object),
#  '2024-06-28': array(['NVDA'], dtype=object),
#  '2024-07-31': array(['TSLA'], dtype=object),
#  '2024-08-30': array(['VNQ'], dtype=object),
#  '2024-09-30': array(['TSLA'], dtype=object),
#  '2024-10-31': array(['ARKB'], dtype=object),
#  '2024-11-29': array(['TSLA'], dtype=object)}

# %%
# Initialize lists to store metrics
annual_returns = []
sharpe_ratios = []
max_drawdowns = []
calmar_ratios = []
sortino_ratios = []

for number in range(18):
    print(f"*******************{number}************************")
    annual_return, sharpe_ratio, max_drawdown_value, calmar_ratio, sortino_ratio = calculate_metrics(returns=retss[number])

    # Append metrics to their respective lists
    annual_returns.append(annual_return)
    sharpe_ratios.append(sharpe_ratio)
    max_drawdowns.append(max_drawdown_value)
    calmar_ratios.append(calmar_ratio)
    sortino_ratios.append(sortino_ratio)

    # Print results
    print(f"Annual Return: {annual_return * 100:.2f}%")
    print(f"Sharpe Ratio: {sharpe_ratio:.2f}")
    print(f"Max Drawdown: {max_drawdown_value * 100:.2f}%")
    print(f"Calmar Ratio: {calmar_ratio:.2f}")
    print(f"Sortino Ratio: {sortino_ratio:.2f}")

# Calculate averages
avg_annual_return = sum(annual_returns) / len(annual_returns)
avg_sharpe_ratio = sum(sharpe_ratios) / len(sharpe_ratios)
avg_max_drawdown = sum(max_drawdowns) / len(max_drawdowns)
avg_calmar_ratio = sum(calmar_ratios) / len(calmar_ratios)
avg_sortino_ratio = sum(sortino_ratios) / len(sortino_ratios)

# Print averages
print("\n********** Averages **********")
print(f"Average Annual Return: {avg_annual_return * 100:.2f}%")
print(f"Average Sharpe Ratio: {avg_sharpe_ratio:.2f}")
print(f"Average Max Drawdown: {avg_max_drawdown * 100:.2f}%")
print(f"Average Calmar Ratio: {avg_calmar_ratio:.2f}")
print(f"Average Sortino Ratio: {avg_sortino_ratio:.2f}")
# Out:
# *******************0************************
# Annual Return: 115.70%
# Sharpe Ratio: 2.13
# Max Drawdown: 11.01%
# Calmar Ratio: 10.50
# Sortino Ratio: 15.45
# *******************1************************
# Annual Return: 68.64%
# Sharpe Ratio: 1.43
# Max Drawdown: 19.75%
# Calmar Ratio: 3.47
# Sortino Ratio: 4.99
# *******************2************************
# Annual Return: 118.38%
# Sharpe Ratio: 2.10
# Max Drawdown: 18.82%
# Calmar Ratio: 6.29
# Sortino Ratio: 7.58
# *******************3************************
# Annual Return: 62.16%
# Sharpe Ratio: 1.40
# Max Drawdown: 17.76%
# Calmar Ratio: 3.50
# Sortino Ratio: 4.14
# *******************4************************
# Annual Return: 99.43%
# Sharpe Ratio: 1.83
# Max Drawdown: 21.30%
# Calmar Ratio: 4.67
# Sortino Ratio: 5.83
# *******************5************************
# Annual Return: 31.87%
# Sharpe Ratio: 1.11
# Max Drawdown: 16.90%
# Calmar Ratio: 1.89
# Sortino Ratio: 2.63
# *******************6************************
# Annual Return: 15.69%
# Sharpe Ratio: 0.58
# Max Drawdown: 24.28%
# Calmar Ratio: 0.65
# Sortino Ratio: 1.44
# *******************7************************
# Annual Return: 10.14%
# Sharpe Ratio: 0.43
# Max Drawdown: 40.61%
# Calmar Ratio: 0.25
# Sortino Ratio: 1.28
# *******************8************************
# Annual Return: -7.96%
# Sharpe Ratio: -0.08
# Max Drawdown: 34.16%
# Calmar Ratio: -0.23
# Sortino Ratio: -0.20
# *******************9************************
# Annual Return: 20.29%
# Sharpe Ratio: 0.63
# Max Drawdown: 31.87%
# Calmar Ratio: 0.64
# Sortino Ratio: 1.41
# *******************10************************
# Annual Return: 57.45%
# Sharpe Ratio: 1.31
# Max Drawdown: 26.20%
# Calmar Ratio: 2.19
# Sortino Ratio: 2.24
# *******************11************************
# Annual Return: 41.00%
# Sharpe Ratio: 1.10
# Max Drawdown: 21.64%
# Calmar Ratio: 1.89
# Sortino Ratio: 1.95
# *******************12************************
# Annual Return: 85.71%
# Sharpe Ratio: 1.76
# Max Drawdown: 19.70%
# Calmar Ratio: 4.35
# Sortino Ratio: 3.63
# *******************13************************
# Annual Return: 64.71%
# Sharpe Ratio: 1.46
# Max Drawdown: 18.98%
# Calmar Ratio: 3.41
# Sortino Ratio: 2.90
# *******************14************************
# Annual Return: 47.86%
# Sharpe Ratio: 1.35
# Max Drawdown: 15.83%
# Calmar Ratio: 3.02
# Sortino Ratio: 2.73
# *******************15************************
# Annual Return: 38.20%
# Sharpe Ratio: 0.97
# Max Drawdown: 24.41%
# Calmar Ratio: 1.56
# Sortino Ratio: 1.63
# *******************16************************
# Annual Return: 9.37%
# Sharpe Ratio: 0.42
# Max Drawdown: 40.71%
# Calmar Ratio: 0.23
# Sortino Ratio: 0.79
# *******************17************************
# Annual Return: 6.60%
# Sharpe Ratio: 0.37
# Max Drawdown: 31.71%
# Calmar Ratio: 0.21
# Sortino Ratio: 0.74
#
# ********** Averages **********
# Average Annual Return: 49.18%
# Average Sharpe Ratio: 1.13
# Average Max Drawdown: 24.20%
# Average Calmar Ratio: 2.69
# Average Sortino Ratio: 3.40

# %%
for number in range(18):
    plot_returns(returns=retss[number], diffRebal=True)
